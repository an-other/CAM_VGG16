# %%
import torchvision
import torch
import torch.nn as nn

# %%
model=torchvision.models.vgg16_bn(pretrained=True)

# %%
for name,block in model.named_modules():
  print(name,block)

for param in model.parameters():
  param.requires_grad=False

# %%
cls=[]
cls.append(nn.Conv2d(512,2,1))
cls.append(nn.AdaptiveAvgPool2d((1,1)))
model.classifier=nn.Sequential(*cls)

# %%
for name,block in model.named_modules():
  print(name,block)

# %%
import torch.optim as optim

# %%
optimizer=optim.SGD(model.classifier.parameters(),lr=0.001,momentum=0.9,weight_decay=5e-4)

# %%
! git clone https://github.com/an-other/CAM_VGG16.git
# Out:
# Cloning into 'CAM_VGG16'...
# remote: Enumerating objects: 19, done.
# remote: Counting objects: 100% (19/19), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 19 (delta 4), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (19/19), done.

# %%
import zipfile
file=zipfile.ZipFile('/content/drive/MyDrive/dogcat_test.zip')
file.extractall('/content/CAM_VGG16')

# %%
import zipfile
file=zipfile.ZipFile('/content/drive/MyDrive/dogcat_train.zip')
file.extractall('/content/CAM_VGG16')

# %%
# !python main.py

# %%
import os
os.chdir('/content/CAM_VGG16')

# %%
tmp=torch.randn(16,3,224,224)

# %%
y=model(tmp)

# %%
y.shape
# Out:
# torch.Size([16, 1000])

# %%
cls=[]
cls.append(nn.Conv2d(512,2,1))
cls.append(nn.AdaptiveAvgPool2d((1,1)))
model.classifier=nn.Sequential(*cls)

# %%
y2=model(tmp)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-23-9a13a04150c6> in <module>()
# ----> 1 y2=model(tmp)
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# /usr/local/lib/python3.7/dist-packages/torchvision/models/vgg.py in forward(self, x)
#      50         x = self.avgpool(x)
#      51         x = torch.flatten(x, 1)
# ---> 52         x = self.classifier(x)
#      53         return x
#      54
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
# ...

# %%
model=torchvision.models.vgg16_bn(pretrained=True).features

# %%
model
# Out:
# Sequential(
#   (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU(inplace=True)
#   (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (5): ReLU(inplace=True)
#   (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (7): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (8): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (9): ReLU(inplace=True)
#   (10): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (11): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (12): ReLU(inplace=True)
#   (13): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
# ...
